# %%
pip install textstat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
import textstat

# %%
import os
phrases_path = os.path.abspath("phrases2.txt")

# %%
text="my watch fell in the water"

# %%
textstat.flesch_kincaid_grade(text)
# Out:
# 0.9

# %%
h = open(phrases_path, "r")
for line in h:
    print(textstat.flesch_kincaid_grade(text))

h.close()
# Out:
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# 0.9
# ...
